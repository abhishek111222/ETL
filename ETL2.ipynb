# %%
import pandas as pd

# %%
diversity_df = pd.read_csv("diversityindex.csv")
diversity_df.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
#    Asian alone, percent, 2013  \
# 0                        31.1
# 1                        25.2
# 2                        28.8
# 3                        28.2
# 4                        41.4
#
#    Native Hawaiian and Other Pacific Islander alone, percent,  \
# 0                                                2.3
# 1                                                0.2
# 2                                               10.6
# 3                                                1.0
# 4                                                0.7
#
#    Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 0                               4.8                               14.6
# 1                               2.7                               28.0
# 2                              23.3                               10.7
# 3                               5.2                               22.7
# 4                               3.7                               13.5
#
#    White alone, not Hispanic or Latino, percent, 2013
# 0                                               29.2
# 1                                               26.7
# 2                                               31.5
# 3                                               33.2
# 4                                               12.9

# %%
new_df = diversity_df

# %%
new_df["County"], new_df["State"] = diversity_df["Location"].str.rsplit(", ").str
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   """Entry point for launching an IPython kernel.

# %%
new_df
# Out:
#                             Location  Diversity-Index  \
# 0     Aleutians West Census Area, AK         0.769346
# 1                  Queens County, NY         0.742224
# 2                    Maui County, HI         0.740757
# 3                 Alameda County, CA         0.740399
# 4         Aleutians East Borough, AK         0.738867
# ...                              ...              ...
# 3190                Osage County, MO         0.037540
# 3191              Lincoln County, WV         0.035585
# 3192               Leslie County, KY         0.035581
# 3193               Blaine County, NE         0.023784
# 3194            Keya Paha County, NE         0.021816
#
#       Black or African American alone, percent, 2013  \
# 0                                                7.4
# 1                                               20.9
# 2                                                0.8
# 3                                               12.4
# 4                                                7.7
# ...                                              ...
# 3190                                             0.3
# 3191                                             0.2
# 3192                                             0.4
# 3193                                             0.2
# 3194                                             0.0
#
#       American Indian and Alaska Native alone, percent, 2013  \
# 0                                                  13.8
# 1                                                   1.3
# 2                                                   0.6
# 3                                                   1.2
# 4                                                  21.8
# ...                                                 ...
# 3190                                                0.2
# 3191                                                0.1
# 3192                                                0.1
# 3193                                                0.0
# 3194                                                0.1
#
#       Asian alone, percent, 2013  \
# 0                           31.1
# 1                           25.2
# 2                           28.8
# 3                           28.2
# 4                           41.4
# ...                          ...
# 3190                         0.1
# 3191                         0.1
# 3192                         0.2
# 3193                         0.0
# 3194                         0.1
#
#       Native Hawaiian and Other Pacific Islander alone, percent,  \
# 0                                                   2.3
# 1                                                   0.2
# 2                                                  10.6
# 3                                                   1.0
# 4                                                   0.7
# ...                                                 ...
# 3190                                                0.0
# 3191                                                0.0
# 3192                                                0.0
# 3193                                                0.0
# 3194                                                0.0
#
#       Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 0                                  4.8                               14.6
# 1                                  2.7                               28.0
# 2                                 23.3                               10.7
# 3                                  5.2                               22.7
# 4                                  3.7                               13.5
# ...                                ...                                ...
# 3190                               0.7                                0.6
# 3191                               0.7                                0.6
# 3192                               0.7                                0.5
# 3193                               0.8                                0.2
# 3194                               0.6                                0.5
#
#       White alone, not Hispanic or Latino, percent, 2013  \
# 0                                                  29.2
# 1                                                  26.7
# 2                                                  31.5
# 3                                                  33.2
# 4                                                  12.9
# ...                                                 ...
# 3190                                               98.1
# 3191                                               98.2
# 3192                                               98.2
# 3193                                               98.8
# 3194                                               98.9
#
#                           County State
# 0     Aleutians West Census Area    AK
# 1                  Queens County    NY
# 2                    Maui County    HI
# 3                 Alameda County    CA
# 4         Aleutians East Borough    AK
# ...                          ...   ...
# 3190                Osage County    MO
# 3191              Lincoln County    WV
# 3192               Leslie County    KY
# 3193               Blaine County    NE
# 3194            Keya Paha County    NE
#
# [3195 rows x 11 columns]

# %%
new_df["State"]
# Out:
# 0       AK
# 1       NY
# 2       HI
# 3       CA
# 4       AK
#         ..
# 3190    MO
# 3191    WV
# 3192    KY
# 3193    NE
# 3194    NE
# Name: State, Length: 3195, dtype: object

# %%
new_df.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
#    Asian alone, percent, 2013  \
# 0                        31.1
# 1                        25.2
# 2                        28.8
# 3                        28.2
# 4                        41.4
#
#    Native Hawaiian and Other Pacific Islander alone, percent,  \
# 0                                                2.3
# 1                                                0.2
# 2                                               10.6
# 3                                                1.0
# 4                                                0.7
#
#    Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 0                               4.8                               14.6
# 1                               2.7                               28.0
# 2                              23.3                               10.7
# 3                               5.2                               22.7
# 4                               3.7                               13.5
#
#    White alone, not Hispanic or Latino, percent, 2013  \
# 0                                               29.2
# 1                                               26.7
# 2                                               31.5
# 3                                               33.2
# 4                                               12.9
#
#                        County State
# 0  Aleutians West Census Area    AK
# 1               Queens County    NY
# 2                 Maui County    HI
# 3              Alameda County    CA
# 4      Aleutians East Borough    AK

# %%
new_df2 = pd.DataFrame({"Diversity - Index" : new_df.groupby(["State", "County"])["Diversity-Index"].mean(),
                        "Black" : new_df.groupby(["State", "County"])["Black or African American alone, percent, 2013"].mean(),
                        "American Indian" : new_df.groupby(["State", "County"])["Diversity-Index"].mean(),
                        "Asian" : new_df.groupby(["State", "County"])["American Indian and Alaska Native alone, percent, 2013"].mean(),
                        "Native Hawaiian":new_df.groupby(["State","County"])["Native Hawaiian and Other Pacific Islander alone, percent,"].mean(),
                       "Two or More Races":new_df.groupby(["State","County"])["Two or More Races, percent, 2013"].mean(),
                       "Hispanic/ Latino":new_df.groupby(["State","County"])["Hispanic or Latino, percent, 2013"].mean(),
                       "White":new_df.groupby(["State","County"])["White alone, not Hispanic or Latino, percent, 2013"].mean()})

# %%
new_df2
# Out:
#                                   Diversity - Index  Black  American Indian  \
# State County
# AK    Aleutians East Borough               0.738867    7.7         0.738867
#       Aleutians West Census Area           0.769346    7.4         0.769346
#       Anchorage Municipality               0.601515    6.3         0.601515
#       Bethel Census Area                   0.315556    0.7         0.315556
#       Bristol Bay Borough                  0.648271    0.0         0.648271
# ...                                             ...    ...              ...
# WY    Sweetwater County                    0.340296    1.7         0.340296
#       Teton County                         0.325230    1.5         0.325230
#       Uinta County                         0.225552    0.8         0.225552
#       Washakie County                      0.296868    0.8         0.296868
#       Weston County                        0.147697    0.6         0.147697
#
#                                   Asian  Native Hawaiian  Two or More Races  \
# State County
# AK    Aleutians East Borough       21.8              0.7                3.7
#       Aleutians West Census Area   13.8              2.3                4.8
#       Anchorage Municipality        8.1              2.3                7.8
#       Bethel Census Area           81.8              0.3                4.1
#       Bristol Bay Borough          33.8              0.3               17.5
# ...                                 ...              ...                ...
# WY    Sweetwater County             1.2              0.2                1.7
#       Teton County                  1.0              0.1                1.5
#       Uinta County                  1.3              0.2                1.7
#       Washakie County               1.7              0.1                1.7
#       Weston County                 1.7              0.0                2.1
#
#                                   Hispanic/ Latino  White
# State County
# AK    Aleutians East Borough                  13.5   12.9
#       Aleutians West Census Area              14.6   29.2
#       Anchorage Municipality                   8.6   60.5
#       Bethel Census Area                       1.6   11.5
#       Bristol Bay Borough                      3.9   45.3
# ...                                            ...    ...
# WY    Sweetwater County                       15.9   79.6
#       Teton County                            15.1   80.7
#       Uinta County                             9.1   87.5
#       Washakie County                         14.2   82.6
#       Weston County                            3.8   92.2
#
# [3143 rows x 8 columns]

# %%
new_df2.head()
# Out:
#                                   Diversity - Index  Black  American Indian  \
# State County
# AK    Aleutians East Borough               0.738867    7.7         0.738867
#       Aleutians West Census Area           0.769346    7.4         0.769346
#       Anchorage Municipality               0.601515    6.3         0.601515
#       Bethel Census Area                   0.315556    0.7         0.315556
#       Bristol Bay Borough                  0.648271    0.0         0.648271
#
#                                   Asian  Native Hawaiian  Two or More Races  \
# State County
# AK    Aleutians East Borough       21.8              0.7                3.7
#       Aleutians West Census Area   13.8              2.3                4.8
#       Anchorage Municipality        8.1              2.3                7.8
#       Bethel Census Area           81.8              0.3                4.1
#       Bristol Bay Borough          33.8              0.3               17.5
#
#                                   Hispanic/ Latino  White
# State County
# AK    Aleutians East Borough                  13.5   12.9
#       Aleutians West Census Area              14.6   29.2
#       Anchorage Municipality                   8.6   60.5
#       Bethel Census Area                       1.6   11.5
#       Bristol Bay Borough                      3.9   45.3

# %%
unemp_df = pd.read_csv("output.csv")
unemp_df.head()
# Out:
#    Year     Month        State         County  Rate
# 0  2015  February  Mississippi  Newton County   6.1
# 1  2015  February  Mississippi  Panola County   9.4
# 2  2015  February  Mississippi  Monroe County   7.9
# 3  2015  February  Mississippi   Hinds County   6.1
# 4  2015  February  Mississippi  Kemper County  10.6

# %%
unemp_df = unemp_df[["County", "State", "Rate"]].copy()
unemp_df.head()
# Out:
#           County        State  Rate
# 0  Newton County  Mississippi   6.1
# 1  Panola County  Mississippi   9.4
# 2  Monroe County  Mississippi   7.9
# 3   Hinds County  Mississippi   6.1
# 4  Kemper County  Mississippi  10.6

# %%
len(unemp_df)
# Out:
# 885548

# %%
us_state_abbrev = {
   'Alabama': 'AL',
   'Alaska': 'AK',
   'Arizona': 'AZ',
   'Arkansas': 'AR',
   'California': 'CA',
   'Colorado': 'CO',
   'Connecticut': 'CT',
   'Delaware': 'DE',
   'Florida': 'FL',
   'Georgia': 'GA',
   'Hawaii': 'HI',
   'Idaho': 'ID',
   'Illinois': 'IL',
   'Indiana': 'IN',
   'Iowa': 'IA',
   'Kansas': 'KS',
   'Kentucky': 'KY',
   'Louisiana': 'LA',
   'Maine': 'ME',
   'Maryland': 'MD',
   'Massachusetts': 'MA',
   'Michigan': 'MI',
   'Minnesota': 'MN',
   'Mississippi': 'MS',
   'Missouri': 'MO',
   'Montana': 'MT',
   'Nebraska': 'NE',
   'Nevada': 'NV',
   'New Hampshire': 'NH',
   'New Jersey': 'NJ',
   'New Mexico': 'NM',
   'New York': 'NY',
   'North Carolina': 'NC',
   'North Dakota': 'ND',
   'Ohio': 'OH',
   'Oklahoma': 'OK',
   'Oregon': 'OR',
   'Pennsylvania': 'PA',
   'Rhode Island': 'RI',
   'South Carolina': 'SC',
   'South Dakota': 'SD',
   'Tennessee': 'TN',
   'Texas': 'TX',
   'Utah': 'UT',
   'Vermont': 'VT',
   'Virginia': 'VA',
   'Washington': 'WA',
   'West Virginia': 'WV',
   'Wisconsin': 'WI',
   'Wyoming': 'WY',
}

# %%
unemp_df2 = unemp_df

# %%
for key, value in us_state_abbrev.items():
  unemp_df2.loc[unemp_df2["State"] == key, "State"] = value

# %%
unemp_df2.head()
# Out:
#           County State  Rate
# 0  Newton County    MS   6.1
# 1  Panola County    MS   9.4
# 2  Monroe County    MS   7.9
# 3   Hinds County    MS   6.1
# 4  Kemper County    MS  10.6

# %%
unemp_df_new = pd.DataFrame({"Unemployment Rate" : unemp_df.groupby(["State", "County"])["Rate"].mean()})
unemp_df_new.head()
# Out:
#                       Unemployment Rate
# State County
# AL    Autauga County           5.417284
#       Baldwin County           5.364198
#       Barbour County           8.460185
#       Bibb County              7.684877
#       Blount County            5.164506

# %%
median_inc = pd.read_csv("/content/2015 Median Income by County.csv")
median_inc.head()
# Out:
#               County-State          County  Population  \
# 0  Autauga County, Alabama  Autauga County       55221
# 1  Baldwin County, Alabama  Baldwin County      195121
# 2  Barbour County, Alabama  Barbour County       26932
# 3     Bibb County, Alabama     Bibb County       22604
# 4   Blount County, Alabama   Blount County       57710
#
#    Median household income State Code    State
# 0                  51281.0         AL  Alabama
# 1                  50254.0         AL  Alabama
# 2                  32964.0         AL  Alabama
# 3                  38678.0         AL  Alabama
# 4                  45813.0         AL  Alabama

# %%
median_inc = median_inc[["County", "Population", "Median household income", "State Code"]]
median_inc.head()
# Out:
#            County  Population  Median household income State Code
# 0  Autauga County       55221                  51281.0         AL
# 1  Baldwin County      195121                  50254.0         AL
# 2  Barbour County       26932                  32964.0         AL
# 3     Bibb County       22604                  38678.0         AL
# 4   Blount County       57710                  45813.0         AL

# %%
median_inc = median_inc.rename(columns = {"State Code" : "State"})
median_inc.head()
# Out:
#            County  Population  Median household income State
# 0  Autauga County       55221                  51281.0    AL
# 1  Baldwin County      195121                  50254.0    AL
# 2  Barbour County       26932                  32964.0    AL
# 3     Bibb County       22604                  38678.0    AL
# 4   Blount County       57710                  45813.0    AL

# %%
median_inc_new = pd.DataFrame({"Median household income" : median_inc.groupby(["State", "County"])["Median household income"].mean(),
                               "Population" : median_inc.groupby(["State", "County"])["Population"].sum()})

# %%
median_inc_new.head()
# Out:
#                                   Median household income  Population
# State County
# AK    Aleutians East Borough                      61518.0        3304
#       Aleutians West Census Area                  84306.0        5684
#       Anchorage Municipality                      78326.0      299107
#       Bethel Census Area                          51012.0       17776
#       Bristol Bay Borough                         79750.0         970

# %%
merged = pd.merge(unemp_df_new, median_inc_new, on = ["State", "County"], how = "inner")

# %%
merged.head()
# Out:
#                       Unemployment Rate  Median household income  Population
# State County
# AL    Autauga County           5.417284                  51281.0       55221
#       Baldwin County           5.364198                  50254.0      195121
#       Barbour County           8.460185                  32964.0       26932
#       Bibb County              7.684877                  38678.0       22604
#       Blount County            5.164506                  45813.0       57710

# %%
merged
# Out:
#                          Unemployment Rate  Median household income  \
# State County
# AL    Autauga County              5.417284                  51281.0
#       Baldwin County              5.364198                  50254.0
#       Barbour County              8.460185                  32964.0
#       Bibb County                 7.684877                  38678.0
#       Blount County               5.164506                  45813.0
# ...                                    ...                      ...
# WY    Sweetwater County           4.749691                  69022.0
#       Teton County                3.645062                  75325.0
#       Uinta County                5.538580                  56569.0
#       Washakie County             4.995062                  47652.0
#       Weston County               4.448765                  57738.0
#
#                          Population
# State County
# AL    Autauga County          55221
#       Baldwin County         195121
#       Barbour County          26932
#       Bibb County             22604
#       Blount County           57710
# ...                             ...
# WY    Sweetwater County       44772
#       Teton County            22311
#       Uinta County            20930
#       Washakie County          8400
#       Weston County            7152
#
# [2806 rows x 3 columns]

# %%
merged2 = pd.merge(merged, new_df2, on = ["State", "County"], how = "inner")

# %%
merged2.head()
# Out:
#                       Unemployment Rate  Median household income  Population  \
# State County
# AL    Autauga County           5.417284                  51281.0       55221
#       Baldwin County           5.364198                  50254.0      195121
#       Barbour County           8.460185                  32964.0       26932
#       Bibb County              7.684877                  38678.0       22604
#       Blount County            5.164506                  45813.0       57710
#
#                       Diversity - Index  Black  American Indian  Asian  \
# State County
# AL    Autauga County           0.388898   18.4         0.388898    0.5
#       Baldwin County           0.297942    9.5         0.297942    0.7
#       Barbour County           0.556605   47.6         0.556605    0.6
#       Bibb County              0.394100   22.1         0.394100    0.4
#       Blount County            0.221056    1.8         0.221056    0.6
#
#                       Native Hawaiian  Two or More Races  Hispanic/ Latino  \
# State County
# AL    Autauga County              0.1                1.7               2.7
#       Baldwin County              0.1                1.5               4.6
#       Barbour County              0.2                0.9               4.8
#       Bibb County                 0.1                0.9               2.1
#       Blount County               0.1                1.1               8.7
#
#                       White
# State County
# AL    Autauga County   75.9
#       Baldwin County   83.1
#       Barbour County   46.3
#       Bibb County      74.6
#       Blount County    87.8

# %%
merged_final = merged2.reset_index()

# %%
merged_final.head()
# Out:
#   State          County  Unemployment Rate  Median household income  \
# 0    AL  Autauga County           5.417284                  51281.0
# 1    AL  Baldwin County           5.364198                  50254.0
# 2    AL  Barbour County           8.460185                  32964.0
# 3    AL     Bibb County           7.684877                  38678.0
# 4    AL   Blount County           5.164506                  45813.0
#
#    Population  Diversity - Index  Black  American Indian  Asian  \
# 0       55221           0.388898   18.4         0.388898    0.5
# 1      195121           0.297942    9.5         0.297942    0.7
# 2       26932           0.556605   47.6         0.556605    0.6
# 3       22604           0.394100   22.1         0.394100    0.4
# 4       57710           0.221056    1.8         0.221056    0.6
#
#    Native Hawaiian  Two or More Races  Hispanic/ Latino  White
# 0              0.1                1.7               2.7   75.9
# 1              0.1                1.5               4.6   83.1
# 2              0.2                0.9               4.8   46.3
# 3              0.1                0.9               2.1   74.6
# 4              0.1                1.1               8.7   87.8

# %%
merged_final = merged_final[["State","County","Population","Median household income","Unemployment Rate",
                            "Diversity - Index","White","Black","Hispanic/ Latino","Asian","American Indian",
                            "Native Hawaiian","Two or More Races"]]

# %%
merged_final
# Out:
#      State             County  Population  Median household income  \
# 0       AL     Autauga County       55221                  51281.0
# 1       AL     Baldwin County      195121                  50254.0
# 2       AL     Barbour County       26932                  32964.0
# 3       AL        Bibb County       22604                  38678.0
# 4       AL      Blount County       57710                  45813.0
# ...    ...                ...         ...                      ...
# 2801    WY  Sweetwater County       44772                  69022.0
# 2802    WY       Teton County       22311                  75325.0
# 2803    WY       Uinta County       20930                  56569.0
# 2804    WY    Washakie County        8400                  47652.0
# 2805    WY      Weston County        7152                  57738.0
#
#       Unemployment Rate  Diversity - Index  White  Black  Hispanic/ Latino  \
# 0              5.417284           0.388898   75.9   18.4               2.7
# 1              5.364198           0.297942   83.1    9.5               4.6
# 2              8.460185           0.556605   46.3   47.6               4.8
# 3              7.684877           0.394100   74.6   22.1               2.1
# 4              5.164506           0.221056   87.8    1.8               8.7
# ...                 ...                ...    ...    ...               ...
# 2801           4.749691           0.340296   79.6    1.7              15.9
# 2802           3.645062           0.325230   80.7    1.5              15.1
# 2803           5.538580           0.225552   87.5    0.8               9.1
# 2804           4.995062           0.296868   82.6    0.8              14.2
# 2805           4.448765           0.147697   92.2    0.6               3.8
#
#       Asian  American Indian  Native Hawaiian  Two or More Races
# 0       0.5         0.388898              0.1                1.7
# 1       0.7         0.297942              0.1                1.5
# 2       0.6         0.556605              0.2                0.9
# 3       0.4         0.394100              0.1                0.9
# 4       0.6         0.221056              0.1                1.1
# ...     ...              ...              ...                ...
# 2801    1.2         0.340296              0.2                1.7
# 2802    1.0         0.325230              0.1                1.5
# 2803    1.3         0.225552              0.2                1.7
# 2804    1.7         0.296868              0.1                1.7
# 2805    1.7         0.147697              0.0                2.1
#
# [2806 rows x 13 columns]
